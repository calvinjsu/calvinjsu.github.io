# %%
import matplotlib.pyplot as plt
from ipywidgets import interact

def plot(a=1, b=0):
    x = arange(0,10)
    y = a*x + b
    plt.plot(x,y)

interact(plot, a=(-5,5), b=(-100,100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-8e553950a4a5> in <module>
#      59 axdeath = plt.axes([0.185, 0.01, 0.65, 0.03], facecolor=axcolor)
#      60
# ---> 61 sbeta = Slider(axbeta, 'beta', 0, 1, valinit=beta, valstep=0.01)
#      62 sgamma = Slider(axgamma, 'gamma', 0, 1, valinit=gamma, valstep=0.01)
#      63 ssigma = Slider(axsigma, 'sigma', 0, 1, valinit=sigma, valstep=0.01)
#
# NameError: name 'Slider' is not defined
